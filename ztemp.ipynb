# %%
from halib import *
from src.results.timeline.report_helper import TlReportGen

exp_dir = r"./zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136"
TlReportGen.gen_TlReport_exp(
    exp_dir,
)
TlReportGen.tlreport_from_csv(f"{exp_dir}/timeline_report.csv")
# Out:
# [Warning][Video=VSD3__lb_none__video20] Mismatched frame count for gt (7478) vs series data for
# col_name=no_temp_method (7477). Using inner join to align frames.
# ──────────────────────────────────────────── <Saving_report_results:> ─────────────────────────────────────────────
# [INFO] Report generated at: ⏬
# 📄
# ]8;id=554262;file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136/timeline_report.html\file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.1]8;;\
# ]8;id=554262;file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136/timeline_report.html\42136/timeline_report.html]8;;\
# [INFO] CSV version saved at: ⏬
# 📄
# ]8;id=587335;file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136/timeline_report.csv\file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.1]8;;\
# ]8;id=587335;file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136/timeline_report.csv\42136/timeline_report.csv]8;;\
# ──────────────────────────────────────────── </Saving_report_results:> ────────────────────────────────────────────
# ───────────────────────────────────────────── <Reconstructed_Report> ──────────────────────────────────────────────
# [INFO] Report generated at: ⏬
# 📄
# ]8;id=584231;file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136/timeline_report_reconstructed.html\file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.1]8;;\
# ]8;id=584231;file:///E:/SyncData/paper2_main/zout/zruns/4GPU_SV__ds_UFireIndoorFull__mt_no_temp_method__af4b0d32a3d2__20260209.142136/timeline_report_reconstructed.html\42136/timeline_report_reconstructed.html]8;;\
# ───────────────────────────────────────────── </Reconstructed_Report> ─────────────────────────────────────────────
