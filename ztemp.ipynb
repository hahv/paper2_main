# %%
from halib import *
from src.results.timeline.report_helper import TimelineReportGen

df = TimelineReportGen.get_timeline_csv_path_df(
    "zout/zruns/MainPC__ds_UFireIndoorVal__mt_temp_method_motion_block__8a43c37ef1c3__20260204.045008"
)

df
# Out:
# ---------------------------------------------------------------------------
# MissingFields                             Traceback (most recent call last)
# Cell In[1], line 4
#       1 from halib import *
#       2 from src.results.timeline.report_helper import TimelineReportGen
# ----> 4 df = TimelineReportGen.get_timeline_csv_path_df(
#       5     "zout/zruns/MainPC__ds_UFireIndoorVal__mt_temp_method_motion_block__8a43c37ef1c3__20260204.045008"
#       6 )
#       8 df
#
# File /mnt/e/SyncData/paper2_main/src/results/timeline/report_helper.py:25, in TimelineReportGen.get_timeline_csv_path_df(exp_dir)
#      23 config_file = Path(exp_dir) / "__config.yaml"
#      24 assert config_file.exists(), f"Config file not found: {config_file}"
# ---> 25 exp_cfg = Config.from_custom_yaml_file(str(config_file))
#      26 dataset_dir = exp_cfg.dbsetCfg.dir_path
#      27 all_videos = fs.filter_files_by_extension(
#      28     dataset_dir, [".mp4", ".avi", ".mov", ".mkv"], recursive=True
#      29 )
#
# File /mnt/e/SyncData/paper2_main/src/config.py:359, in Config.from_custom_yaml_file(cls, yaml_file_or_dict)
#     354 @classmethod
#     355 def from_custom_yaml_file(cls, yaml_file_or_dict: str) -> "Config":  # ty:ignore[invalid-method-override]
#     356     """
#     357     Wrapper for from_custom_yaml_file_or_str
#     358     """
# --> 359     return cls.from_custom_yaml_file_or_str(yaml_file_or_dict)
#
# File /mnt/e/SyncData/paper2_main/src/config.py:434, in Config.from_custom_yaml_file_or_str(cls, yaml_file_or_dict)
#     432 else:
#     433     raise ValueError("Input must be a file path, YAML string, or dict.")
# --> 434 return cls.from_yaml_str(yaml_str)
#
# File /mnt/e/SyncData/paper2_main/src/config.py:363, in Config.from_yaml_str(cls, yaml_str)
#     361 @classmethod
#     362 def from_yaml_str(cls, yaml_str: str) -> "Config":
# --> 363     instance = Config.from_yaml(yaml_str)
#     364     instance.orignal_yaml_str = yaml_str  # ty:ignore[invalid-assignment]
#     365     # 2. Configuration for dynamic loading
#     366     # Map: Attribute Name -> (Class Type, Folder Name Suffix)
#     367     # Note: Logic assumes list attribute is "list_" + suffix + "s"
#
# File /mnt/e/SyncData/paper2_main/.venv/lib/python3.11/site-packages/dataclass_wizard/wizard_mixins.py:255, in YAMLWizard.from_yaml(cls, string_or_stream, decoder, **decoder_kwargs)
#     251     decoder = yaml.safe_load
#     253 o = decoder(string_or_stream, **decoder_kwargs)
# --> 255 return fromdict(cls, o) if isinstance(o, dict) else fromlist(cls, o)
#
# File /mnt/e/SyncData/paper2_main/.venv/lib/python3.11/site-packages/dataclass_wizard/loader_selection.py:31, in fromdict(cls, d)
#      28 except KeyError:
#      29     load = _get_load_fn_for_dataclass(cls)
# ---> 31 return load(d)
#
# File <string>:35, in cls_fromdict(o)
#
# MissingFields: `Config.__init__()` missing required fields.
#   Provided: ['dbset_selector', 'general', 'method_selector', 'metric_selector', 'orignal_yaml_str']
#   Missing: ['inferCfg', 'modelCfg']
#   Input JSON: {"dbset-selector": {"dbset-used": {"dir-path": "/mnt/e/zDatasets/paper2_datasets/val", "extra-cfgs": {"csv_loader_cls": "ufireindoor_csv_loader.UFireIndoorCsvLoader", "ds_metric_src": "csv_metric_src", "ds_recursive": true}, "name": "UFireIndoorVal", "vname2path": null}, "list-dbsets": [{"dir-path": "datasets/DFire/DFire_Full_ValTest/test", "extra-cfgs": {"csv_loader_cls": "dfire_csv_loader.DFireCsvLoader", "ds_metric_src": "csv_metric_src"}, "name": "DFire", "vname2path": null}, {"dir-path": "datasets/FireNet", "extra-cfgs": null, "name": "FireNet", "vname2path": null}, {"dir-path": "datasets/UFireIndoor1", "extra-cfgs": {"csv_loader_cls": "ufireindoor_csv_loader.UFireIndoorCsvLoader", "ds_metric_src": "csv_metric_src", "ds_recursive": true}, "name": "UFireIndoor2", "vname2path": null}, {"dir-path": "/mnt/d/zdataset_paper2/build_video_dataset/my_firesmoke_indoor", "extra-cfgs": {"ds_metric_src": "csv_metric_src", "ds_recursive": true}, "name": "UFireIndoorFull", "vname2path": null}, {"dir-path": "/mnt/e/zDatasets/paper2_datasets/test", "extra-cfgs": {"csv_loader_cls": "ufireindoor_csv_loader.UFireIndoorCsvLoader", "ds_metric_src": "csv_metric_src", "ds_recursive": true}, "name": "UFireIndoorTest", "vname2path": null}, {"dir-path": "/mnt/e/zDatasets/paper2_datasets/val", "extra-cfgs": {"csv_loader_cls": "ufireindoor_csv_loader.UFireIndoorCsvLoader", "ds_metric_src": "csv_metric_src", "ds_recursive": true}, "name": "UFireIndoorVal", "vname2path": null}], "selected-dbset": "UFireIndoorVal"}, "general": {"computer-name": "MainPC", "is-optim-mode": true, "log-cfg": {"wandb-cfg": {"mode": "online", "project": "paper2_main", "wandb-key": "85a60f274011647ab0472ad62fe73da5b1704808"}}, "outdir": "zout/zruns", "project-dir": "/mnt/e/SyncData/paper2_main", "seed": 1, "skip-exp-if-exists": true, "time-stamp": "20260204.045008"}, "infer-cfg": {"calc-metrics": true, "csv-columns": ["class_names", "logits", "probs", "pred_label_idx", "pred_label"], "do-infer": true, "limit": -1, "log-transforms": true, "num-infer-workers": 4, "save-csv-results": true, "save-video-results": false, "skip-if-exists": true, "use-profiler": true, "verbose": false}, "method-selector": {"list-methods": [{"extra-cfgs": {"result_proc": {"video": ["video_infer_rs_proc"]}}, "name": "no_temp_method"}, {"extra-cfgs": {"persist_thres": 0.5, "result_proc": {"video": ["video_infer_rs_proc"]}, "window_size": 20}, "name": "temp_baseline_Tpt_method"}, {"extra-cfgs": {"result_proc": {"video": "video_block_skip_rs_proc"}, "skip_proc": {"name": "motion_only_block_skip_proc.MotionOnlyBlockSkipProc", "params": {"block_ratio_th": 0.05, "block_size_orig": 32, "min_roi_ratio": 0.75, "motion": {"name": "acc_motion_det.AccMotionDet", "params": {"decay": 1, "diff_frame_th": 3, "impact_plus_one": 5, "mask_th": 10, "max_val": 25}}, "scale_factor": 1.0}}}, "name": "temp_method_motion_block"}, {"extra-cfgs": {"result_proc": {"video": ["video_block_skip_rs_proc", "fgmask_block_skip_rs_proc"]}, "skip_proc": {"name": "rule_based_block_skip_proc", "params": {"block_active_thresh": 0.1, "block_size_orig": 32, "motion": {"name": "framediff_det.FrameDiffDet", "params": {"diff_thresh": 3}}, "rule_params": {"active_ratio_threshold": 0.2, "wavelet_channel": "r", "wavelet_energy_thres": 50.0}, "scale_factor": 1.0}}}, "name": "temp_method_rule_block"}], "method-used": {"extra-cfgs": {"result_proc": {"video": "video_block_skip_rs_proc"}, "skip_proc": {"name": "motion_only_block_skip_proc.MotionOnlyBlockSkipProc", "params": {"block_ratio_th": 0.05, "block_size_orig": 32, "min_roi_ratio": 0.75, "motion": {"name": "acc_motion_det.AccMotionDet", "params": {"decay": 1, "diff_frame_th": 3, "impact_plus_one": 5, "mask_th": 10, "max_val": 25}}, "scale_factor": 1.0}}}, "name": "temp_method_motion_block"}, "selected-method": "temp_method_motion_block"}, "metric-selector": {"list-metrics": [{"extra-cfgs": {"mode": ["per_video", "per_frame"]}, "metric-names": ["accuracy", "f1_score", "precision", "reca ...
#   error: Config.__init__() missing 2 required positional arguments: 'inferCfg' and 'modelCfg'
#   Key Transform: to_snake_case()
#   Resolution: For more details, please see https://github.com/rnag/dataclass-wizard/issues/54
