# %%
import os
import cv2
from halib.filetype import csvfile
from halib.utils.video import VideoUtils

df = VideoUtils.get_video_dir_meta_df(
    "datasets/DFire/test")

dir_ls = [
    r"datasets\DFire\test",
    r"datasets\DFire_Static\test",
    r"datasets\FireNet",
    r"datasets\pexels",
]
out_csvfile_name = ['DFire', 'DFireStatic', 'FireNet', 'pexels']
for dir_path, out_name in zip(dir_ls, out_csvfile_name):
    df = VideoUtils.get_video_dir_meta_df(dir_path, search_recursive=True)
    df.to_csv(f"./zreport/datasets/{out_name}_meta.csv", sep=";", index=False)
# Out:
# e:\NextCloud\paper3\.venv_win\lib\site-packages\halib\filetype\csvfile.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row_df], ignore_index=True)
# e:\NextCloud\paper3\.venv_win\lib\site-packages\halib\filetype\csvfile.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row_df], ignore_index=True)
# ...

# %%
from halib import *
df = pd.read_csv(r"E:\NextCloud\paper3\zout\1GPU_SV__ds_DFire__mt_temp_stabilize__20250729.173615\FP2_results.csv", sep=";")
df
# Out:
#                           video  num_frames  frame_idx  do_infer  \
# 0   datasets/DFire/test\FP2.mp4          31          1      True
# 1   datasets/DFire/test\FP2.mp4          31          2      True
# 2   datasets/DFire/test\FP2.mp4          31          3      True
# 3   datasets/DFire/test\FP2.mp4          31          4      True
# 4   datasets/DFire/test\FP2.mp4          31          5      True
# 5   datasets/DFire/test\FP2.mp4          31          6      True
# 6   datasets/DFire/test\FP2.mp4          31          7      True
# 7   datasets/DFire/test\FP2.mp4          31          8      True
# 8   datasets/DFire/test\FP2.mp4          31          9      True
# 9   datasets/DFire/test\FP2.mp4          31         10      True
# 10  datasets/DFire/test\FP2.mp4          31         11      True
# 11  datasets/DFire/test\FP2.mp4          31         12      True
# 12  datasets/DFire/test\FP2.mp4          31         13      True
# ...
