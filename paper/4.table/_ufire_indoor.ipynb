# %%
from halib import *

from halib.utils.video import VideoUtils

PROJ_DIR = "/mnt/e/SyncData/paper2_main"
VideoUtils.get_video_dir_meta_df(
    video_dir=f"{PROJ_DIR}/datasets/UFireIndoorFull",
    search_recursive=True,
    csv_outfile=f"{PROJ_DIR}/paper/4.table/ufire_indoor.csv",
)
# Out:
# /mnt/e/SyncData/paper2_main/.venv/lib/python3.11/site-packages/halib/filetype/csvfile.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row_df], ignore_index=True)
#                                             video_path width  ... frame_count   fps
# 0    /mnt/e/SyncData/paper2_main/datasets/UFireIndo...  1920  ...         360  30.0
# 1    /mnt/e/SyncData/paper2_main/datasets/UFireIndo...  1920  ...         360  30.0
# 2    /mnt/e/SyncData/paper2_main/datasets/UFireIndo...  1920  ...         360  30.0
# 3    /mnt/e/SyncData/paper2_main/datasets/UFireIndo...  1920  ...         360  30.0
# 4    /mnt/e/SyncData/paper2_main/datasets/UFireIndo...  1920  ...         360  30.0
# ...
