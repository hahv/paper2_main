# %%
from halib import *
from halib.filetype import csvfile
from halib.utils.video import VideoUtils


video_dir = r"/mnt/d/zdataset_paper2/build_video_dataset/__firesmoke_dataset_pool/video_USTC_smoke_lin2017smoke/video_test_set"


df = VideoUtils.get_video_dir_meta_df(video_dir=video_dir)
csvfile.fn_display_df(df)
df.to_csv("./dataset.csv", sep=";")
# Out:
# +----+------------------------------------------+---------+----------+---------------+-------+
# |    | video_path                               |   width |   height |   frame_count |   fps |
# +====+==========================================+=========+==========+===============+=======+
# |  0 | /mnt/d/zdataset_paper2/build_video_datas |    1920 |     1080 |          1501 |    25 |
# |    | et/__firesmoke_dataset_pool/video_USTC_s |         |          |               |       |
# |    | moke_lin2017smoke/video_test_set/test-   |         |          |               |       |
# |    | 1.avi                                    |         |          |               |       |
# +----+------------------------------------------+---------+----------+---------------+-------+
# |  1 | /mnt/d/zdataset_paper2/build_video_datas |    1920 |     1080 |           721 |    24 |
# |    | et/__firesmoke_dataset_pool/video_USTC_s |         |          |               |       |
# ...
